# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import operator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# paste your training and testing dataset name here
train_df=pd.read_csv("train.csv")
test_df=pd.read_csv("test.csv")

#paste inside l=[] names of all the column you want to be predicted and used for predictions, ie names of all the labels


def evaluate():
    n=[]
    imp=[]
    li=[]
    plot=[]
    for name, importance in zip(X_train.columns, m):
        n.append(name)
        imp.append(importance)
        
    results= dict(zip(n, imp))
    
    print 'Here is the results: '
    print imp
    plt.plot(imp);
    
    print "heyy ths is the model name  :"+ algo_name[item]
    
    st= 'graph_'+str(algo_name[item])+"_"+str(l[index])+'.png'
    plt.savefig(st)

    sorted_results = sorted(results.items(), key=operator.itemgetter(1))
    print '******************************'
    print ''
    print 'Top 5 Important contributor to the features are : '
    print ''
    print sorted_results[-1]
    print sorted_results[-2]
    print sorted_results[-3]
    print sorted_results[-4]
    print sorted_results[-5]
  
    print '_______________________________________________________________________________________________'
    print '_______________________________________________________________________________________________'



l=['Support Level(IE?)','Assignment group','Priority','Hour Resolved','Weightage','Highest Assignment group','Automation Pickup Time (Min)','Technician Pickup Time (Min)']

for index in range (1,8):

    y=train_df[l[index]]
    X=train_df.drop(l[index], axis=1)

    print 'Now Predicting : '  + l[index]+'\n'

    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
    
    algo_name=['LinearRegression()','LogisticRegression()','LinearDiscriminantAnalysis()','KNeighborsClassifier()','DecisionTreeClassifier()','GaussianNB()','SVC()']
    
    algo=[LinearRegression(),LogisticRegression(),LinearDiscriminantAnalysis(),KNeighborsClassifier(),DecisionTreeClassifier(),GaussianNB(),SVC()]

    for item in range(0,7):

        model=algo[item]

        model.fit(X_train, y_train)

        print  '\n'+ algo_name[item]

        print model.score(X_test, y_test)

        y_pred=model.predict(X_test)
        
        df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
        df.index=range(78)
        
        df1 = df.head(15)
        df1.plot(kind='bar',figsize=(8,5))
        plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
        plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
        st1= 'main_graph_'+str(algo_name[item])+"_"+str(l[index])+'.png'
        plt.savefig(st1)
        plt.show()
        

        
        print df.head()
        
        print '----------------------------------------------------------'
        
        #uncomment to save csv files of the results
        #name=l[index]+'.csv'

        #df.to_csv(name)
        
        
        
        
        m=[]
        
        if algo_name[item]=='LinearRegression()':
            m=model.coef_
            evaluate()

        elif algo_name[item]=='DecisionTreeClassifier()':
            m=model.feature_importances_
            evaluate()
        
        elif algo_name[item]=='KNeighborsClassifier()':
            print 'Coefficeints of variable in this algo provide no useful information'  
            

    print '_______________________________________________________________________________________________'
    print '_______________________________________________________________________________________________'
# Out:
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# Now Predicting : Assignment group
#
#
# LinearRegression()
# 0.7676417420695734
#    Actual  Predicted
# 0       2   2.232233
# 1       5   4.860841
# 2       5   4.490647
# 3       5   4.849925
# 4       6   6.534727
# ----------------------------------------------------------
# Here is the results:
# ...
